# %%
import matplotlib.pyplot as plt
import numpy as np 
plt.style.use('ggplot')
gunler = ["Pzt", "Sal", "Çar", "Per", "Cum",]
gunduz_hava = [20, 18, 21, 17, 14]
gece_hava = [9, 11, 13, 8, 6]
x = np.arange(len(gunduz_hava))
genislik = 0.35

fig, ax = plt.subplots()
cizgi1 = ax.plot(gunler, gunduz_hava, color = "blue", label = "Gündüz", linestyle = "--", marker = "o", linewidth=2)
cizgi2 = ax.plot(gunler, gece_hava, color = "red", label = "Gece", linestyle = "--", marker = "o", linewidth=2)


ax.set_title("Haftalik Gece ve Gündüz Sicaklik Tablosu")
ax.set_ylabel("Sicaklik")
ax.set_xlabel("Gunler")
ax.set_xticklabels(gunler)



ax.legend()
plt.savefig("hava_durumu_takibi.png", dpi=200)
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_22392\2275677403.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(gunler)
