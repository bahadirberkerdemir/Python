# %%
import matplotlib.pyplot as plt
import numpy as np 
gunler = ["Pzt", "Sal", "Çar", "Per", "Cum", "Cmt", "Paz"]
sicaklik = [22, 24, 21, 25, 28, 26, 23]
x = np.arange(len(gunler)) 
genislik = 0.35

fig, ax= plt.subplots()

cizgi = ax.plot(gunler, sicaklik, color = 'blue', linestyle = '--', marker = 'o')

ax.set_title("Haftalik Sicaklik Tablosu")
ax.set_ylabel("Sicaklik")
ax.set_xlabel("Gunler")
ax.set_xticklabels(gunler)


plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_15284\2108003743.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(gunler)
